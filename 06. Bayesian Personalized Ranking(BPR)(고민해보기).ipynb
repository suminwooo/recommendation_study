# %% [markdown]
# 참고 : https://github.com/shah314/BPR

# %%
from BPR_source_code.filereader import read_ratings, read_movies
from BPR_source_code.bpr import bpr_update
from BPR_source_code.hitrate import hit_rate
from BPR_source_code.util import cov_matrix, random_vector

from random import seed
import numpy as np
import random as random

# %%
users = read_ratings("./movielens_data/ratings.csv")
movies = read_movies("./movielens_data/movies.csv")

# %%
iterations = 5

for i in range(iterations):
    print("Iteration " + str(i))
    bpr_update(users, movies)
# Out:
# Iteration 0
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4

# %%
hits, denom, rms, rmsall = hit_rate(users, movies)

# %%
print("Trained:")
print("HitRate" + str(hits/denom))
print("Number of Users:" + str(len(users)))
print("Number of Movies:" + str(len(movies)))
# Out:
# Trained:
# HitRate0.5451559934318555
# Number of Users:609
# Number of Movies:9742

# %%
hits
# Out:
# 332

# %%
denom
# Out:
# 609

# %%
rms
# Out:
# 4.385041004312039

# %%
rmsall
# Out:
# 3.6862287922393335
